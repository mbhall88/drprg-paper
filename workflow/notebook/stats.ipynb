# %%
import pandas as pd
from collections import defaultdict
from itertools import combinations
import numpy as np
from statsmodels.stats.contingency_tables import mcnemar

# %%
qc = pd.read_csv("../../results/QC/illumina.qc.csv", index_col="run")

# %%
min_depth = 15
max_contam = 0.05
valid_samples = qc.query("coverage>=@min_depth and f_contam<=@max_contam").index

# %%
df = pd.read_csv("../../results/tables/sn_sp/classifications.illumina.csv")
df.query("run in @valid_samples", inplace=True)
df.set_index(["run", "drug", "tool"], drop=False, inplace=True)

# %%
df
# Out:
#                                          run        drug classification  \
# run        drug       tool
# ERR4798664 kanamycin  drprg       ERR4798664   kanamycin             TN
# SRR6982346 kanamycin  drprg       SRR6982346   kanamycin             TN
# ERR4796956 kanamycin  drprg       ERR4796956   kanamycin             TN
# ERR4796656 kanamycin  drprg       ERR4796656   kanamycin             TN
# ERR4829787 kanamycin  drprg       ERR4829787   kanamycin             TN
# ...                                      ...         ...            ...
# ERR2512943 rifampicin tbprofiler  ERR2512943  rifampicin             TN
# ERR8700384 rifampicin tbprofiler  ERR8700384  rifampicin             TN
# SRR6397652 rifampicin tbprofiler  SRR6397652  rifampicin             TN
# ERR4797809 rifampicin tbprofiler  ERR4797809  rifampicin             TP
# ERR4822382 rifampicin tbprofiler  ERR4822382  rifampicin             TP
#
#                                         tool
# run        drug       tool
# ERR4798664 kanamycin  drprg            drprg
# SRR6982346 kanamycin  drprg            drprg
# ERR4796956 kanamycin  drprg            drprg
# ERR4796656 kanamycin  drprg            drprg
# ERR4829787 kanamycin  drprg            drprg
# ...                                      ...
# ERR2512943 rifampicin tbprofiler  tbprofiler
# ERR8700384 rifampicin tbprofiler  tbprofiler
# SRR6397652 rifampicin tbprofiler  tbprofiler
# ERR4797809 rifampicin tbprofiler  tbprofiler
# ERR4822382 rifampicin tbprofiler  tbprofiler
#
# [839850 rows x 4 columns]

# %%
DRUGS = set(df["drug"])
TOOLS = set(df["tool"])

# %%
M = defaultdict(dict)
for drug in DRUGS:
    d = {}
    for t in combinations(TOOLS, 2):
        sp = np.zeros((2, 2), dtype=int)
        sn = np.zeros((2, 2), dtype=int)
        t1, t2 = sorted(t)
        runs = df.query("tool==@t1 and drug==@drug")["run"]
        for r in runs:
            c1 = df.at[(r, drug, t1), "classification"]
            c2 = df.at[(r, drug, t2), "classification"]
            
            match (c1, c2):
                case ("TP", "TP"):  # sensitivity a
                    sn[0][0] += 1
                case ("TP", "FN"):  # sensitivity c
                    sn[1][0] += 1
                case ("FN", "TP"):  # sensitivity b
                    sn[0][1] += 1
                case ("FN", "FN"):  # sensitivity d
                    sn[1][1] += 1
                case ("TN", "TN"):  # specificity a
                    sp[0][0] += 1
                case ("TN", "FP"):  # specificity c
                    sp[1][0] += 1
                case ("FP", "TN"):  # specificity b
                    sp[0][1] += 1
                case ("FP", "FP"):  # specificity d
                    sp[1][1] += 1
                case _:
                    raise ValueError((c1, c2))

        d["sn"] = sn
        d["sp"] = sp
        M[(t1, t2)][drug] = d

# %%
for (t1, t2), d in M.items():
    for drug, mats in d.items():
        sn = mats["sn"]
        sp = mats["sp"]
        sn_res = mcnemar(sn, exact=True)
        
        print(f"T1: {t1}\tT2: {t2}\t{drug}\nSensitivity")
        print(sn_res)
        print("Specificity")
        
        sp_res = mcnemar(sp, exact=True)
        print(sp_res)
# Out:
# T1: drprg	T2: tbprofiler	capreomycin
# Sensitivity
# pvalue      1.0323214044661785e-21
# statistic   1.0
# Specificity
# pvalue      2.837623469531536e-10
# statistic   1.0
# T1: drprg	T2: tbprofiler	moxifloxacin
# Sensitivity
# pvalue      2.9802322387695312e-08
# statistic   1.0
# Specificity
# pvalue      0.00031255115754902363
# statistic   7.0
# T1: drprg	T2: tbprofiler	linezolid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: drprg	T2: tbprofiler	ethambutol
# Sensitivity
# pvalue      2.744048833847046e-05
# statistic   3.0
# Specificity
# pvalue      0.0005350527353584766
# statistic   6.0
# T1: drprg	T2: tbprofiler	pyrazinamide
# Sensitivity
# pvalue      0.08380154521018608
# statistic   84.0
# Specificity
# pvalue      3.1798876310461662e-06
# statistic   27.0
# T1: drprg	T2: tbprofiler	amikacin
# Sensitivity
# pvalue      6.462348535570529e-27
# statistic   0.0
# Specificity
# pvalue      1.5366822481155396e-08
# statistic   1.0
# T1: drprg	T2: tbprofiler	isoniazid
# Sensitivity
# pvalue      1.992019573556286e-10
# statistic   26.0
# Specificity
# pvalue      2.5560148060321808e-06
# statistic   3.0
# T1: drprg	T2: tbprofiler	levofloxacin
# Sensitivity
# pvalue      7.916241884231567e-09
# statistic   1.0
# Specificity
# pvalue      1.0928604751825333e-05
# statistic   4.0
# T1: drprg	T2: tbprofiler	streptomycin
# Sensitivity
# pvalue      9.356427960246984e-22
# statistic   25.0
# Specificity
# pvalue      0.865373510902735
# statistic   68.0
# T1: drprg	T2: tbprofiler	rifampicin
# Sensitivity
# pvalue      1.7761089796163855e-13
# statistic   41.0
# Specificity
# pvalue      0.0070003666914999485
# statistic   8.0
# T1: drprg	T2: tbprofiler	ethionamide
# Sensitivity
# pvalue      1.1003523795356136e-16
# statistic   29.0
# Specificity
# pvalue      7.657072931048342e-05
# statistic   26.0
# T1: drprg	T2: tbprofiler	ofloxacin
# Sensitivity
# pvalue      0.00390625
# statistic   0.0
# Specificity
# pvalue      0.0390625
# statistic   1.0
# T1: drprg	T2: tbprofiler	delamanid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: drprg	T2: tbprofiler	kanamycin
# Sensitivity
# pvalue      4.948866508539911e-23
# statistic   2.0
# Specificity
# pvalue      1.0967254638671875e-05
# statistic   1.0
# T1: mykrobe	T2: tbprofiler	capreomycin
# Sensitivity
# pvalue      1.0323214044661785e-21
# statistic   1.0
# Specificity
# pvalue      2.837623469531536e-10
# statistic   1.0
# T1: mykrobe	T2: tbprofiler	moxifloxacin
# Sensitivity
# pvalue      2.9802322387695312e-08
# statistic   1.0
# Specificity
# pvalue      0.00031255115754902363
# statistic   7.0
# T1: mykrobe	T2: tbprofiler	linezolid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: mykrobe	T2: tbprofiler	ethambutol
# Sensitivity
# pvalue      2.744048833847046e-05
# statistic   3.0
# Specificity
# pvalue      0.0005350527353584766
# statistic   6.0
# T1: mykrobe	T2: tbprofiler	pyrazinamide
# Sensitivity
# pvalue      0.08380154521018608
# statistic   84.0
# Specificity
# pvalue      3.1798876310461662e-06
# statistic   27.0
# T1: mykrobe	T2: tbprofiler	amikacin
# Sensitivity
# pvalue      6.462348535570529e-27
# statistic   0.0
# Specificity
# pvalue      1.5366822481155396e-08
# statistic   1.0
# T1: mykrobe	T2: tbprofiler	isoniazid
# Sensitivity
# pvalue      1.992019573556286e-10
# statistic   26.0
# Specificity
# pvalue      2.5560148060321808e-06
# statistic   3.0
# T1: mykrobe	T2: tbprofiler	levofloxacin
# Sensitivity
# pvalue      7.916241884231567e-09
# statistic   1.0
# Specificity
# pvalue      1.0928604751825333e-05
# statistic   4.0
# T1: mykrobe	T2: tbprofiler	streptomycin
# Sensitivity
# pvalue      9.356427960246984e-22
# statistic   25.0
# Specificity
# pvalue      0.865373510902735
# statistic   68.0
# T1: mykrobe	T2: tbprofiler	rifampicin
# Sensitivity
# pvalue      1.7761089796163855e-13
# statistic   41.0
# Specificity
# pvalue      0.0070003666914999485
# statistic   8.0
# T1: mykrobe	T2: tbprofiler	ethionamide
# Sensitivity
# pvalue      1.1003523795356136e-16
# statistic   29.0
# Specificity
# pvalue      7.657072931048342e-05
# statistic   26.0
# T1: mykrobe	T2: tbprofiler	ofloxacin
# Sensitivity
# pvalue      0.00390625
# statistic   0.0
# Specificity
# pvalue      0.0390625
# statistic   1.0
# T1: mykrobe	T2: tbprofiler	delamanid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: mykrobe	T2: tbprofiler	kanamycin
# Sensitivity
# pvalue      4.948866508539911e-23
# statistic   2.0
# Specificity
# pvalue      1.0967254638671875e-05
# statistic   1.0
# T1: drprg	T2: mykrobe	capreomycin
# Sensitivity
# pvalue      1.0323214044661785e-21
# statistic   1.0
# Specificity
# pvalue      2.837623469531536e-10
# statistic   1.0
# T1: drprg	T2: mykrobe	moxifloxacin
# Sensitivity
# pvalue      2.9802322387695312e-08
# statistic   1.0
# Specificity
# pvalue      0.00031255115754902363
# statistic   7.0
# T1: drprg	T2: mykrobe	linezolid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: drprg	T2: mykrobe	ethambutol
# Sensitivity
# pvalue      2.744048833847046e-05
# statistic   3.0
# Specificity
# pvalue      0.0005350527353584766
# statistic   6.0
# T1: drprg	T2: mykrobe	pyrazinamide
# Sensitivity
# pvalue      0.08380154521018608
# statistic   84.0
# Specificity
# pvalue      3.1798876310461662e-06
# statistic   27.0
# T1: drprg	T2: mykrobe	amikacin
# Sensitivity
# pvalue      6.462348535570529e-27
# statistic   0.0
# Specificity
# pvalue      1.5366822481155396e-08
# statistic   1.0
# T1: drprg	T2: mykrobe	isoniazid
# Sensitivity
# pvalue      1.992019573556286e-10
# statistic   26.0
# Specificity
# pvalue      2.5560148060321808e-06
# statistic   3.0
# T1: drprg	T2: mykrobe	levofloxacin
# Sensitivity
# pvalue      7.916241884231567e-09
# statistic   1.0
# Specificity
# pvalue      1.0928604751825333e-05
# statistic   4.0
# T1: drprg	T2: mykrobe	streptomycin
# Sensitivity
# pvalue      9.356427960246984e-22
# statistic   25.0
# Specificity
# pvalue      0.865373510902735
# statistic   68.0
# T1: drprg	T2: mykrobe	rifampicin
# Sensitivity
# pvalue      1.7761089796163855e-13
# statistic   41.0
# Specificity
# pvalue      0.0070003666914999485
# statistic   8.0
# T1: drprg	T2: mykrobe	ethionamide
# Sensitivity
# pvalue      1.1003523795356136e-16
# statistic   29.0
# Specificity
# pvalue      7.657072931048342e-05
# statistic   26.0
# T1: drprg	T2: mykrobe	ofloxacin
# Sensitivity
# pvalue      0.00390625
# statistic   0.0
# Specificity
# pvalue      0.0390625
# statistic   1.0
# T1: drprg	T2: mykrobe	delamanid
# Sensitivity
# pvalue      1.0
# statistic   0.0
# Specificity
# pvalue      1.0
# statistic   0.0
# T1: drprg	T2: mykrobe	kanamycin
# Sensitivity
# pvalue      4.948866508539911e-23
# statistic   2.0
# Specificity
# pvalue      1.0967254638671875e-05
# statistic   1.0

# %%
dir(sn_res)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'pvalue',
#  'statistic']

# %%
sn_res.pvalue
# Out:
# 1.478092302309394e-18

# %%
sn_res.statistic
# Out:
# 77.28735632183908

# %%
t1
# Out:
# 'drprg'

# %%
t2
# Out:
# 'mykrobe'

# %%
drug
# Out:
# 'kanamycin'

# %%
sp_res.pvalue
# Out:
# 5.103985260291326e-05

# %%
sp_res.statistic
# Out:
# 16.40909090909091
